# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('carprices.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
plt.scatter(df['Mileage'], df['Sell Price($)'])
plt.xlabel('Sell Price($)')
plt.ylabel('Mileage')
plt.show()

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])
plt.xlabel('Sell Price($)')
plt.ylabel('Age(yrs)')
plt.show()

# %%
x = df[['Mileage', 'Age(yrs)']].values
y = df['Sell Price($)'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([26514.49825318, 38769.85015629, 13766.63911077, 25673.42829613])

# %%
y_test
# Out:
# array([26100, 35000, 12000, 26750], dtype=int64)

# %%
model.score(x_test, y_test)
# Out:
# 0.9317019328299733
